# %% [markdown]
# <a href="https://colab.research.google.com/github/BrianSandiford/Technical-Assignment---Barbados/blob/main/health_registry_eda_clean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# Load dataset
df = pd.read_csv('/content/drive/MyDrive/health_registry.csv')
df.head()
# Out:
#   facility_id                         facility_name          facility_type  \
# 0     HF-0000         Burgess-Ingram Medical Center  Community Health Ctr.
# 1      033477                           Collins Inc                  Hosp.
# 2          #2              Butler-Leon Clinic (St.)               Hospital
# 3           2              Butler-Leon Clinic (St.)               Hospital
# 4     HF-0003  Powell, Morales and Butler Infirmary            Health Ctr.
#
#        capacity            region licence_issue_date inspection_date  \
# 0      250 beds           St.Lucy           04-01-21     08 Mar 2024
# 1           NaN          St.Peter        28 Mar 2024        17-04-23
# 2       117Beds  St. James Parish         2016-02-18        30/12/22
# 3       117Beds  St. James Parish         2016-02-18        30/12/22
# 4  179 capacity          ST. LUCY   November 21 2020        07-03-24
#
#                 gps_location         remarks
# 0        13.08576, -58.75331             NaN
# 1  POINT(-58.84001 12.87196)            Good
# 2        -58.82307, 13.00952            Good
# 3        -58.82307, 13.00952            Good
# 4        12.77293, -59.04279  Follow-up 2023

# %%
# Clean facility_id
df['facility_id'] = df['facility_id'].astype(str).str.strip().str.upper()

# %%
# Normalize capacity field
def extract_capacity(value):
    # Return None if the value is missing
    if pd.isnull(value):
      return None

     # Convert the value to a string
    text =str(value)

    # Keep only the digits
    number = ''
    for char in text:
        if char.isdigit():
            number += char

    # Return the number as an integer, or None if no digits were found
    if number:
        return int(number)
    else:
       return None

df['capacity'] = df['capacity'].apply(extract_capacity)

# %%
# Standardizing Dates

def robust_parse_date(date_str):
    if pd.isna(date_str):
        return pd.NaT, True

    # Convert to string and strip whitespace
    str_date = str(date_str).strip()

    # List of formats to try
    formats = [
        "%Y-%m-%d", "%Y/%m/%d",      # ISO formats
        "%d-%m-%y", "%d/%m/%y",      # Short year (e.g., 15-04-23)
        "%d-%m-%Y", "%d/%m/%Y",      # Full day-first
        "%B %d %Y"                   # Natural language: September 19 2022
    ]

    for fmt in formats:
        try:
            return datetime.strptime(str_date, fmt), False
        except ValueError:
            continue

    return pd.NaT, True

df[['licence_issue_date_clean', 'licence_issue_invalid']] = df['licence_issue_date'].apply(
    lambda x: pd.Series(robust_parse_date(x))
)

# %%
df[['inspection_date_clean', 'inspection_date_invalid']] = df['inspection_date'].apply(
    lambda x: pd.Series(robust_parse_date(x))
)

# %%
def extract_coords(value):
    if pd.isna(value):
        return pd.Series([None, None])

    str_val = str(value).strip()

    # Try POINT format
    if 'POINT' in str_val:
        try:
            coords = str_val.replace('POINT(', '').replace(')', '').split()
            return pd.Series([float(coords[1]), float(coords[0])])
        except:
            return pd.Series([None, None])

    # Try comma-separated format
    if ',' in str_val:
        try:
            parts = [float(p.strip()) for p in str_val.split(',')]
            if len(parts) == 2:
                return pd.Series(parts)
        except:
            pass  # Move on to DMS check

    # Try DMS format (handle both clean and garbled)
    try:
        if 'â' in str_val or 'Â' in str_val:  # garbage characters detected
            str_val = str_val.encode('latin1').decode('utf8')
        match = re.findall(r"(\d+)°(\d+)′(\d+)″([NSWE])", str_val)
        if len(match) == 2:
            def convert(d, m, s, direction):
                decimal = int(d) + int(m)/60 + int(s)/3600
                return -decimal if direction in ['S', 'W'] else decimal

            lat = convert(*match[0])
            lon = convert(*match[1])
            return pd.Series([lat, lon])
    except:
        pass

    return pd.Series([None, None])

# %%
df[['latitude', 'longitude']] = df['gps_location'].apply(extract_coords)

# %%
df[['gps_location', 'latitude', 'longitude']].head(20)
# Out:
#                  gps_location   latitude  longitude
# 0         13.08576, -58.75331  13.085760 -58.753310
# 1   POINT(-58.84001 12.87196)  12.871960 -58.840010
# 2         -58.82307, 13.00952 -58.823070  13.009520
# 3         -58.82307, 13.00952 -58.823070  13.009520
# 4         12.77293, -59.04279  12.772930 -59.042790
# 5         12.77293, -59.04279  12.772930 -59.042790
# 6       13°12′43″N 58°51′50″W  13.211944 -58.863889
# 7          13°2′6″N 59°0′38″W  13.035000 -59.010556
# 8          13°2′6″N 59°0′38″W  13.035000 -59.010556
# 9          13°14′8″N 59°2′1″W  13.235556 -59.033611
# 10        -59.10919, 13.04721 -59.109190  13.047210
# 11        13.21772, -59.18644  13.217720 -59.186440
# 12      12°53′44″N 58°59′13″W  12.895556 -58.986944
# 13        12.71967, -58.88816  12.719670 -58.888160
# 14       13°14′19″N 59°2′18″W  13.238611 -59.038333
# 15  POINT(-59.22110 13.22506)  13.225060 -59.221100
# 16  POINT(-58.87985 13.17264)  13.172640 -58.879850
# 17  POINT(-58.91250 13.17008)  13.170080 -58.912500
# 18      12°58′58″N 59°13′20″W  12.982778 -59.222222
# 19       12°51′29″N 59°7′49″W  12.858056 -59.130278

# %%
# Normalize region names
df['region_clean'] = (
    df['region']
    .astype(str)
    .str.strip()
    .str.replace(r'\bparish\b', '', case=False, regex=True)  # removes 'Parish' in any case
    .str.strip()
    .str.title()
)
df[['region', 'region_clean']].drop_duplicates().head()
# Out:
#              region region_clean
# 0           St.Lucy      St.Lucy
# 1          St.Peter     St.Peter
# 2  St. James Parish    St. James
# 4          ST. LUCY     St. Lucy
# 6         St Andrew    St Andrew

# %%
df_clean = df.drop_duplicates()
df_clean.shape
# Out:
# (11185, 16)

# %%
# Optional: list of known clean region names to validate against
known_regions = {
    "St. Michael", "St. Joseph", "St. Lucy", "St. Andrew",
    "St. Peter", "St. James", "St. George", "St. Philip",
    "St. Thomas", "Christ Church"
}

def clean_region(value):
    if pd.isna(value):
        return None

    text = str(value).strip()

    # Remove the word "Parish" (any capitalization)
    text = re.sub(r'\bparish\b', '', text, flags=re.IGNORECASE).strip()

    # Try forward-cleaned version
    forward = text.title()

    # Try reversed version
    reversed_text = text[::-1].strip()
    reversed_cleaned = re.sub(r'\bparish\b', '', reversed_text, flags=re.IGNORECASE).strip().title()

    # If reversed_cleaned is a known valid region, return it
    if reversed_cleaned in known_regions:
        return reversed_cleaned

    # Otherwise return forward-cleaned
    return forward

# %%
df['region_clean'] = df['region'].apply(clean_region)

# %%
df.head(30)
# Out:
#    facility_id                                      facility_name  \
# 0      HF-0000                      Burgess-Ingram Medical Center
# 1       033477                                        Collins Inc
# 2           #2                           Butler-Leon Clinic (St.)
# 3            2                           Butler-Leon Clinic (St.)
# 4      HF-0003               Powell, Morales and Butler Infirmary
# 5      HF-0003               Powell, Morales and Butler Infirmary
# 6        00004             Williams, Woods and Bradley Polyclinic
# 7          NAN                   May and Sons Medical Center (St)
# 8          NAN                   May and Sons Medical Center (St)
# 9        00006            Herrera,-Taylor-and-Sanchez (St.Andrew)
# 10         007                      Wagner-Franklin Health Centre
# 11         NAN             Hurley, Jensen and Perkins Hosp. (st.)
# 12     HF-0009                             Lee-Macias Polyclinic©
# 13         NAN      White,-Wilcox-and-Martin Medical Center (St.)
# 14         011                      Brown-Wilson 🏥 (ChristChurch)
# 15         #12                         Newton,-Peters-and-Rivera©
# 16         #13              Barr, Conley and Mendoza Clinic (ST.)
# 17      333DB8                 Zimmerman and Sons Infirmary (St.)
# 18         015  Martinez, Williams and Ellis Polyclinic (St.Ja...
# 19      AF30F0                                        Bradley PLC
# 20       00017                                       Wagner LLC 🏥
# 21      6F82F6                           Case and Sons Polyclinic
# 22       00019                      Rodriguez, Mayer and Hamilton
# 23      2BA130                               Brown PLC Polyclinic
# 24      2BA130                               Brown PLC Polyclinic
# 25         NAN                        Guerrero PLC Hospital (ST.)
# 26         022                                 Baker-Taylor Hosp.
# 27         022                                 Baker-Taylor Hosp.
# 28         #23                          Allen, Riley and Kennedy©
# 29          23                          Allen, Riley and Kennedy©
#
#               facility_type  capacity            region licence_issue_date  \
# 0     Community Health Ctr.     250.0           St.Lucy           04-01-21
# 1                     Hosp.       NaN          St.Peter        28 Mar 2024
# 2                  Hospital     117.0  St. James Parish         2016-02-18
# 3                  Hospital     117.0  St. James Parish         2016-02-18
# 4               Health Ctr.     179.0          ST. LUCY   November 21 2020
# 5               Health Ctr.     179.0          ST. LUCY   November 21 2020
# 6                  Hospital       NaN         St Andrew           17-04-21
# 7              Polyclinic 🏥       NaN          St Peter           20160217
# 8              Polyclinic 🏥       NaN          St Peter           20160217
# 9             Health Centre       NaN         St.Andrew           06/11/21
# 10                   Clinic     461.0         St. James           18/05/18
# 11                    Hosp.     338.0          st. lucy           09-09-25
# 12  Community Health Centre       NaN        st. andrew   November 13 2019
# 13             Polyclinic 🏥     408.0        St. Andrew           18-01-24
# 14  Community Health Centre      27.0      ChristChurch           27-09-20
# 15    Community Health Ctr.     392.0    Christ Church            23-08-24
# 16               Polyclinic       NaN         ST. JAMES     August 16 2024
# 17               Polyclinic      84.0         St. Lucy            02-10-19
# 18                 Hospital       NaN          St.James           01-07-17
# 19                   Clinic       NaN        St. George           20-08-20
# 20                      NaN       NaN      ChristChurch           12-09-16
# 21             Polyclinic 🏥     166.0         St. James        10 Sep 2018
# 22                   Clinic     474.0         St Joseph   December 31 2025
# 23             Polyclinic 🏥       NaN          St James       July 07 2016
# 24             Polyclinic 🏥       NaN          St James       July 07 2016
# 25              Health Ctr.       NaN        ST. GEORGE           20191225
# 26                      NaN       NaN       St. Joseph            02/04/18
# 27                      NaN       NaN       St. Joseph            02/04/18
# 28                 Hospital       NaN  St. Peter Parish        22 Oct 2025
# 29                 Hospital       NaN  ST. PETER PARISH        22 Oct 2025
#
#     inspection_date               gps_location           remarks  \
# 0       08 Mar 2024        13.08576, -58.75331               NaN
# 1          17-04-23  POINT(-58.84001 12.87196)              Good
# 2          30/12/22        -58.82307, 13.00952              Good
# 3          30/12/22        -58.82307, 13.00952              Good
# 4          07-03-24        12.77293, -59.04279    Follow-up 2023
# 5          07-03-24        12.77293, -59.04279    Follow-up 2023
# 6   January 31 2024      13°12′43″N 58°51′50″W               NaN
# 7        2018-01-01         13°2′6″N 59°0′38″W    Follow-up 2023
# 8        2018-01-01         13°2′6″N 59°0′38″W    Follow-up 2023
# 9       22 Mar 2018         13°14′8″N 59°2′1″W                 -
# 10     July 31 2019        -59.10919, 13.04721               NaN
# 11         20250926        13.21772, -59.18644  Reinspection due
# 12         20240815      12°53′44″N 58°59′13″W  Reinspection due
# 13         20191216        12.71967, -58.88816                 -
# 14         13-03-19       13°14′19″N 59°2′18″W  Reinspection due
# 15         20230506  POINT(-59.22110 13.22506)               NaN
# 16         08-01-22  POINT(-58.87985 13.17264)                 -
# 17       2025-11-18  POINT(-58.91250 13.17008)              Good
# 18         08-01-23      12°58′58″N 59°13′20″W    Follow-up 2023
# 19         16/05/18       12°51′29″N 59°7′49″W                 ♥
# 20      24 Jul 2023        13.09928, -58.88444                 ♥
# 21         25-09-24        13.07409, -58.84039               NaN
# 22         27-02-24         -58.71602;12.98428               NaN
# 23      28 May 2024      12°43′45″N 59°17′10″W  Reinspection due
# 24      28 May 2024      12°43′45″N 59°17′10″W  Reinspection due
# 25       2023-05-31        -59.10385, 12.84030  Reinspection due
# 26         20190602        -59.24115, 12.70994               NaN
# 27         20190602        -59.24115, 12.70994               NaN
# 28       2022-10-31                        NaN  Reinspection due
# 29       2022-10-31                        NaN  Reinspection due
#
#    licence_issue_date_clean  licence_issue_invalid inspection_date_clean  \
# 0                2021-01-04                  False                   NaT
# 1                       NaT                   True            2023-04-17
# 2                2016-02-18                  False            2022-12-30
# 3                2016-02-18                  False            2022-12-30
# 4                2020-11-21                  False            2024-03-07
# 5                2020-11-21                  False            2024-03-07
# 6                2021-04-17                  False            2024-01-31
# 7                       NaT                   True            2018-01-01
# 8                       NaT                   True            2018-01-01
# 9                2021-11-06                  False                   NaT
# 10               2018-05-18                  False            2019-07-31
# 11               2025-09-09                  False                   NaT
# 12               2019-11-13                  False                   NaT
# 13               2024-01-18                  False                   NaT
# 14               2020-09-27                  False            2019-03-13
# 15               2024-08-23                  False                   NaT
# 16               2024-08-16                  False            2022-01-08
# 17               2019-10-02                  False            2025-11-18
# 18               2017-07-01                  False            2023-01-08
# 19               2020-08-20                  False            2018-05-16
# 20               2016-09-12                  False                   NaT
# 21                      NaT                   True            2024-09-25
# 22               2025-12-31                  False            2024-02-27
# 23               2016-07-07                  False                   NaT
# 24               2016-07-07                  False                   NaT
# 25                      NaT                   True            2023-05-31
# 26               2018-04-02                  False                   NaT
# 27               2018-04-02                  False                   NaT
# 28                      NaT                   True            2022-10-31
# 29                      NaT                   True            2022-10-31
#
#     inspection_date_invalid   latitude  longitude   region_clean
# 0                      True  13.085760 -58.753310        St.Lucy
# 1                     False  12.871960 -58.840010       St.Peter
# 2                     False -58.823070  13.009520      St. James
# 3                     False -58.823070  13.009520      St. James
# 4                     False  12.772930 -59.042790       St. Lucy
# 5                     False  12.772930 -59.042790       St. Lucy
# 6                     False  13.211944 -58.863889      St Andrew
# 7                     False  13.035000 -59.010556       St Peter
# 8                     False  13.035000 -59.010556       St Peter
# 9                      True  13.235556 -59.033611      St.Andrew
# 10                    False -59.109190  13.047210      St. James
# 11                     True  13.217720 -59.186440       St. Lucy
# 12                     True  12.895556 -58.986944     St. Andrew
# 13                     True  12.719670 -58.888160     St. Andrew
# 14                    False  13.238611 -59.038333   Christchurch
# 15                     True  13.225060 -59.221100  Christ Church
# 16                    False  13.172640 -58.879850      St. James
# 17                    False  13.170080 -58.912500       St. Lucy
# 18                    False  12.982778 -59.222222       St.James
# 19                    False  12.858056 -59.130278     St. George
# 20                     True  13.099280 -58.884440   Christchurch
# 21                    False  13.074090 -58.840390      St. James
# 22                    False        NaN        NaN      St Joseph
# 23                     True  12.729167 -59.286111       St James
# 24                     True  12.729167 -59.286111       St James
# 25                    False -59.103850  12.840300     St. George
# 26                     True -59.241150  12.709940     St. Joseph
# 27                     True -59.241150  12.709940     St. Joseph
# 28                    False        NaN        NaN      St. Peter
# 29                    False        NaN        NaN      St. Peter

# %%
# remove duplicates
df_clean = df.drop_duplicates()

# %%
# Keep only selected columns
df_export = df_clean[[
    'facility_id','facility_name','facility_type','region_clean', 'latitude', 'longitude',
    'capacity', 'licence_issue_date_clean', 'inspection_date_clean','remarks'
]]

# Save the cleaned version to CSV
df_export.to_csv("/content/drive/MyDrive/cleaned_health_registry.csv", index=False)
